# %%
import pandas as pd
import pickle

# Load the test dataset from the pickled file
with open('diabetes_model.pkl', 'rb') as f:
    clf, X_test = pickle.load(f)

# Make predictions on the test dataset
y_pred = clf.predict(X_test)

# Print the predictions
print(y_pred)
# Out:
# ['muskmelon' 'watermelon' 'papaya' 'papaya' 'apple' 'mango' 'apple'
#  'mothbeans' 'mungbean' 'lentil' 'blackgram' 'coconut' 'pomegranate'
#  'jute' 'coconut' 'pomegranate' 'apple' 'maize' 'papaya' 'muskmelon'
#  'coffee' 'papaya' 'orange' 'papaya' 'chickpea' 'jute' 'mungbean' 'orange'
#  'pigeonpeas' 'rice' 'pomegranate' 'mothbeans' 'jute' 'lentil' 'jute'
#  'blackgram' 'jute' 'chickpea' 'chickpea' 'kidneybeans' 'papaya' 'mango'
#  'blackgram' 'maize' 'mungbean' 'maize' 'pigeonpeas' 'coconut' 'muskmelon'
#  'maize' 'blackgram' 'coffee' 'grapes' 'mungbean' 'coffee' 'kidneybeans'
#  'cotton' 'apple' 'banana' 'blackgram' 'watermelon' 'coconut' 'lentil'
#  'orange' 'papaya' 'pigeonpeas' 'orange' 'rice' 'muskmelon' 'pigeonpeas'
#  'muskmelon' 'coconut' 'jute' 'banana' 'blackgram' 'papaya' 'banana'
#  'cotton' 'watermelon' 'orange' 'coffee' 'chickpea' 'rice' 'mothbeans'
#  'orange' 'mango' 'coffee' 'mothbeans' 'blackgram' 'pomegranate' 'maize'
# ...

# %%
import pickle

# Load the metrics from the pickle file
with open('metrics.pkl', 'rb') as file:
    metrics = pickle.load(file)

# Access the individual metrics
svm_train_accuracy = metrics['svm_train_accuracy']
svm_train_precision = metrics['svm_train_precision']
svm_train_recall = metrics['svm_train_recall']
svm_train_f1_score = metrics['svm_train_f1_score']

svm_val_accuracy = metrics['svm_val_accuracy']
svm_val_precision = metrics['svm_val_precision']
svm_val_recall = metrics['svm_val_recall']
svm_val_f1_score = metrics['svm_val_f1_score']

svm_test_accuracy = metrics['svm_test_accuracy']
svm_test_precision = metrics['svm_test_precision']
svm_test_recall = metrics['svm_test_recall']
svm_test_f1_score = metrics['svm_test_f1_score']

# Load the plots from the pickle files
with open('training_plot.pkl', 'rb') as file:
    training_plot = pickle.load(file)

with open('validation_plot.pkl', 'rb') as file:
    validation_plot = pickle.load(file)

with open('test_plot.pkl', 'rb') as file:
    test_plot = pickle.load(file)

# Render the plots in your views.py file
def your_view_function(request):
    # Code for your view function

    # Render the training plot
    training_plot.show()

    # Render the validation plot
    validation_plot.show()

    # Render the test plot
    test_plot.show()

    # Return your response or template
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 13
#      10 svm_train_recall = metrics['svm_train_recall']
#      11 svm_train_f1_score = metrics['svm_train_f1_score']
# ---> 13 svm_val_accuracy = metrics['svm_val_accuracy']
#      14 svm_val_precision = metrics['svm_val_precision']
#      15 svm_val_recall = metrics['svm_val_recall']
#
# KeyError: 'svm_val_accuracy'
