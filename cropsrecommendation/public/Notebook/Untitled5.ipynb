# %%
import pandas as pd
import pickle

# Load the test dataset from the pickled file
with open('diabetes_model.pkl', 'rb') as f:
    clf, X_test = pickle.load(f)

# Make predictions on the test dataset
y_pred = clf.predict(X_test)

# Print the predictions
print(y_pred)
# Out:
# ['muskmelon' 'watermelon' 'papaya' 'papaya' 'apple' 'mango' 'apple'
#  'mothbeans' 'mungbean' 'lentil' 'blackgram' 'coconut' 'pomegranate'
#  'jute' 'coconut' 'pomegranate' 'apple' 'maize' 'papaya' 'muskmelon'
#  'coffee' 'papaya' 'orange' 'papaya' 'chickpea' 'jute' 'mungbean' 'orange'
#  'pigeonpeas' 'rice' 'pomegranate' 'mothbeans' 'jute' 'lentil' 'jute'
#  'blackgram' 'jute' 'chickpea' 'chickpea' 'kidneybeans' 'papaya' 'mango'
#  'blackgram' 'maize' 'mungbean' 'maize' 'pigeonpeas' 'coconut' 'muskmelon'
#  'maize' 'blackgram' 'coffee' 'grapes' 'mungbean' 'coffee' 'kidneybeans'
#  'cotton' 'apple' 'banana' 'blackgram' 'watermelon' 'coconut' 'lentil'
#  'orange' 'papaya' 'pigeonpeas' 'orange' 'rice' 'muskmelon' 'pigeonpeas'
#  'muskmelon' 'coconut' 'jute' 'banana' 'blackgram' 'papaya' 'banana'
#  'cotton' 'watermelon' 'orange' 'coffee' 'chickpea' 'rice' 'mothbeans'
#  'orange' 'mango' 'coffee' 'mothbeans' 'blackgram' 'pomegranate' 'maize'
# ...

# %%
import pickle

# Load the metrics from the pickle file
with open('metricstr.pkl', 'rb') as file:
    metrics = pickle.load(file)
with open('metricsval.pkl', 'rb') as file:
    metrics1 = pickle.load(file)
with open('metricstest.pkl', 'rb') as file:
    metrics2 = pickle.load(file)
# Access the individual metrics
svm_train_accuracy = metrics['svm_train_accuracy']
svm_train_precision = metrics['svm_train_precision']
svm_train_recall = metrics['svm_train_recall']
svm_train_f1_score = metrics['svm_train_f1_score']
svm_val_accuracy = metrics1['svm_val_accuracy']
svm_val_precision = metrics1['svm_val_precision']
svm_val_recall = metrics1['svm_val_recall']
svm_val_f1_score = metrics1['svm_val_f1_score']

svm_test_accuracy = metrics2['svm_test_accuracy']
svm_test_precision = metrics2['svm_test_precision']
svm_test_recall = metrics2['svm_test_recall']
svm_test_f1_score = metrics2['svm_test_f1_score']
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
# Out:
# 0.612987012987013

# %%
import pickle

# Load the metrics from the pickle file
with open('metricstr.pkl', 'rb') as file:
    metrics = pickle.load(file)
with open('metricsval.pkl', 'rb') as file:
    metrics1 = pickle.load(file)
with open('metricstest.pkl', 'rb') as file:
    metrics2 = pickle.load(file)
# Access the individual metrics
svm_train_accuracy = metrics['svm_train_accuracy']
svm_train_precision = metrics['svm_train_precision']
svm_train_recall = metrics['svm_train_recall']
svm_train_f1_score = metrics['svm_train_f1_score']
svm_val_accuracy = metrics1['svm_val_accuracy']
svm_val_precision = metrics1['svm_val_precision']
svm_val_recall = metrics1['svm_val_recall']
svm_val_f1_score = metrics1['svm_val_f1_score']

svm_test_accuracy = metrics2['svm_test_accuracy']
svm_test_precision = metrics2['svm_test_precision']
svm_test_recall = metrics2['svm_test_recall']
svm_test_f1_score = metrics2['svm_test_f1_score']
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)
print(svm_train_accuracy)

# %%
import pickle

# Load the metrics from the pickle file
with open('rfmetricstr.pkl', 'rb') as file:
    metrics = pickle.load(file)
with open('rfmetricsva.pkl', 'rb') as file:
    metrics1 = pickle.load(file)
with open('rfmetricstst.pkl', 'rb') as file:
    metrics2 = pickle.load(file)
# Access the individual metrics
train_accuracy = metrics['train_accuracy']
train_precision = metrics['train_precision']
train_recall = metrics['train_recall']
train_f1_score = metrics['train_f1_score']
val_accuracy = metrics1['valid_accuracy']
val_precision = metrics1['valid_precision']
val_recall = metrics1['valid_recall']
val_f1_score = metrics1['validf1_score']
test_accuracy = metrics2['test_accuracy']
test_precision = metrics2['test_precision']
test_recall = metrics2['test_recall']
test_f1_score = metrics2['test_f1_score']
print(train_accuracy)
print(train_accuracy)
print(train_accuracy)
print(train_accuracy)
print(train_accuracy)
print(train_accuracy)
print(train_accuracy)
print(train_accuracy)
print(train_accuracy)
print(train_accuracy)
# Out:
# 0.9991095280498664
# 0.9991095280498664
# 0.9991095280498664
# 0.9991095280498664
# 0.9991095280498664
# 0.9991095280498664
# 0.9991095280498664
# 0.9991095280498664
# 0.9991095280498664
# 0.9991095280498664
